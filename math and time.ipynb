# %%
# math and time modules

# %%
import math as mt
mt.sqrt(4) #square root of no.
# Out:
# 2.0

# %%
dir(mt) # all inbuilt function insside math module
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
s=[] 
dir(s) #all inbuilt function inside list
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
print(len(dir(s))) # calculate total no. of inbuilt function inside list
# Out:
# 48

# %%
print(round(mt.sqrt(65))) 
print(round(mt.sqrt(65),2)) # round upto 2 decimals
# Out:
# 8
# 8.06

# %%
mt.pow(5,2)
# Out:
# 25.0

# %%
print(mt.ceil(4.999999))
# return round up value but condition is when we have after decimal we have number greater than 0
print(mt.ceil(4.000000))
print(mt.ceil(4.000001))
# Out:
# 5
# 4
# 5

# %%
print(mt.floor(4.99999999))
print(mt.floor(4.0000000))
# return round down value
# Out:
# 4
# 4

# %%
mt.pi #pie
# Out:
# 3.141592653589793

# %%
def ff(r):
    return mt.pi*(r*r)
ff(4)
# Out:
# 50.26548245743669

# %%
mt.exp(2) # return e to the power x
# Out:
# 7.38905609893065

# %%
mt.log(7.38905609893065) # reverse of exponent
# Out:
# 2.0

# %%
mt.fabs(-9) #return the abs value
# Out:
# 9.0

# %%
abs(-9.56)
# Out:
# 9.56

# %%
import time

# %%
start= time.time() #it returns time when python is created in sec
for i in range(1,10):
    print(i)
end=time.time() # time of python +time  when loop ends
print('Start', start)
time.time()-start #time taken by loop  to execute
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Start 1728975108.257787
# 0.0009965896606445312

# %%
time.ctime() #current date and time
# Out:
# 'Tue Oct 15 12:26:48 2024'

# %%
time.localtime() # returns year, month, month_day, hours_min, sec, weekday,(starting mon as 0), year_day,
# Out:
# time.struct_time(tm_year=2024, tm_mon=10, tm_mday=15, tm_hour=12, tm_min=27, tm_sec=22, tm_wday=1, tm_yday=289, tm_isdst=0)

# %%
time.tzname
# Out:
# ('India Standard Time', 'India Daylight Time')

# %%
start= time.time()
str = 'hello how are you'
r=0
while r<=500:
    print(str)
    r=r+1
end=time.time() # time of python + time  when loop ends
print(' run time:', end-start)
# Out:
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# ...

# %%
start= time.time()
str = 'hello how are you'

for i in range(0,501):
    print(str)
    
end=time.time() # time of python + time  when loop ends
print(' run time:', end-start)
# Out:
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# ...
